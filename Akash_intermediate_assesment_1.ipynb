# %% [markdown]
# <a href="https://colab.research.google.com/github/akashvgeorge/ICT_DSA_26/blob/main/Akash_intermediate_assesment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intermediate Python Assessment
#
# Welcome to the assessment!
# This notebook contains 3 challenges. Please read the instructions carefully and complete each task in the provided code cells.
#
#
# **Rules:**
# - Do not change function names or signatures.
# - Write clean, well-documented code.
# - Run all cells before submission.

# %% [markdown]
# ## Challenge 1: Word Frequency Analyzer
# Write a function `top_k_words(filename: str, k: int) -> list` that returns the top k frequent words.
# - Ignore case and punctuation.
# - Sort by frequency, then alphabetically.

# %%
import re
from collections import Counter

def top_k_words(filename: str, k: int) -> list:
    # Your code here
    with open(filename, "r") as f:
        text = f.read()

    text = text.lower()

    words = re.findall(r'\b[a-z]+\b', text)


    word_counts = Counter(words)

    sorted_words = sorted(
        word_counts.items(),
        key=lambda x: (-x[1], x[0])
    )

    return [word for word, count in sorted_words[:k]]
    pass

# Sample Test (create a sample file)
with open("sample.txt", "w") as f:
    f.write("Data science is evolving. Python is versatile. Learning never stops.")

print(top_k_words("sample.txt", 3))  #expected ["is", "data", "science"]
# Out:
# ['is', 'data', 'evolving']

# %% [markdown]
# ## Challenge 2 : Analyze daily expenses and extract insights.
# User enters:
#
# Number of transactions
# Category and amount
#
# Food 200
# Travel 500
# Food 300
# Shopping 700
#
# ### Output
# * Total expense
# * Highest expense category
# * Category-wise total

# %%
def analyze_expenses():
    n = int(input("Enter number of transactions: "))

    expenses = {}

    for _ in range(n):
        category, amount = input().split()
        amount = float(amount)

        # TODO: store category-wise total
        if category in expenses:
            expenses[category] += amount
        else:
            expenses[category] = amount

    # TODO: calculate total expense
    total = sum(expenses.values())


    # TODO: find highest category
    highest_category = max(expenses, key=expenses.get)

    print("Total Expense:", total)
    print("Highest Category:", highest_category)
    print("Category-wise:", expenses)

analyze_expenses()
# Out:
# Enter number of transactions: 3
# food 200
# travel 100
# food 300
# Total Expense: 600.0
# Highest Category: food
# Category-wise: {'food': 500.0, 'travel': 100.0}

# %% [markdown]
# ### Challenge 3: Data Cleaner (Mini Pandas Logic Without Pandas)
#
# 10 ,20 ,abc ,30 ,-5 , 40
#
# * Remove invalid values
# * Remove negative values
#
#
# Show:
# * Clean list
# * Average
# * Max value

# %%
def clean_data():
    n = int(input("Enter number of values: "))

    data = []

    for _ in range(n):
        value = input()

        try:
            num = float(value)

            # TODO: ignore negative values
            if num >= 0:
                data.append(num)


            data.append(num)

        except:
            # TODO: handle invalid values
            print(f"Skipping invalid value: '{value}'")
            pass

    # TODO: calculate average
    if data:
        avg = sum(data) / len(data)
        max_val = max(data)
    else:
        avg = 0
        max_val = None


    # TODO: find max

    print("Clean Data:", data)
    print("Average:", avg)
    print("Max:", max_val)

clean_data()
# Out:
# Enter number of values: 3
# 5
# -6
# ahd
# Skipping invalid value: 'ahd'
# Clean Data: [5.0, 5.0, -6.0]
# Average: 1.3333333333333333
# Max: 5.0
